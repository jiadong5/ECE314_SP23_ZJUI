# %% [markdown]
# # Lab 11: ODEs, Failure Rates, and Evolutionary Games

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.image as img
import numpy as np
import scipy as sp
import scipy.stats as st
from scipy.integrate import odeint
print ('Modules Imported!')
# Out:
# Modules Imported!

# %% [markdown]
# In this lab we're to going analyze evolutionary games using drift analysis. In order to do this, we first need to determine how to integrate ordinary differential equations. So, we begin with a brief exposure of how to achieve this in Python. While we're at it, we'll do a short exercise about failure rate functions.  Then we examine some evolutionary games, using both a stochastic model and a deterministic model, which involves the differential equations.

# %% [markdown]
# ## Integration of ODEs

# %% [markdown]
# This section gives an introdution to integrating ordinary differential equations (odes), with an application to the calculation of a CDF from a failure rate function.  If you recall from your math classes we can describe an ODE as the following:
#
# $\dot{y}=f(y),$
#
# where both $y$ and the function $f$ are vector valued, and $\dot{y}$ is shorthand for $\frac{dy}{dt}.$   The variables being vector valued simply implies that we could have a system of dependent one dimensional (1D) ODEs as opposed to just a single one dimensional variable.  Let's look at the following system:
#
# \begin{eqnarray*}
# \binom{\dot{y_0}}{\dot{y_1}} = \binom{2y_1-0.1y_0}{-y_0}
# \end{eqnarray*}
# with the initial condition $y_{init}=\binom{y_1(0)}{y_2(0)}=\binom{1}{1}.$
#
# Our goal in using Python is not to find a closed form solution to the ODE as you would have probably done in your math class, but to numerically integrate it and produce a graphical solution. In order to do this we use the odeint method from scipy.integrate. It takes a function with an initial value and specified times at which the solution is to be output. Internally, the numerical method will often use a much finer grid of time points to solve the ode -- but that is none of your concern.   The times you put in are the times at with the method needs to provide the values of the solution. Look how it is used below:

# %%
# Simple example integrating a 2d ordinary differential equation (ode) dy/dt=f(y,t) 
# Note that the odeint package is imported in the code at the beginning of this file.

# Function to integrate over
def f(y,t):    
    return np.array([2.*y[1]-.1*y[0],-y[0] ])

time=np.linspace(0.0,20.0,10000)   # The times at which the solution is output.
yinit=np.array([1.0,1.0])   # The initial condition
y=odeint(f,yinit,time)      

plt.plot(y[:,0],y[:,1])
plt.title('trajectory of y up to time 20')
plt.ylabel('y_1')
plt.xlabel('y_0')
# Out:
# Text(0.5, 0, 'y_0')

# %% [markdown]
# Typically in a plot like this you would add an arrow to indicate the direction of time in the graph. However, we know the initial state is $y_{init}=\binom{1}{1}.$ So as time increases, the trajectory moves concentrically inwards in a clockwise fashion. Depending on how much of differential equations you remember, this solution should make sense. The equation happens to have a linear form and can be written as $\dot y = Ay$ where
# $
# A=\left( \begin{array}{cc}  -0.1  &  2  \\  -1  & 0 \end{array} \right).
# $
# The eigenvalues of $A$ are complex with negative real parts, so we would expect a decaying oscillatory behavior. (If you didn't follow that, don't worry about it.)
#
# As a simple application of integrating a 1D (one-dimensional) ode, the following code calculates a CDF $F$ from its failure rate function $h.$ But first, let's look at some theory to remember what a failure rate function is. If we let $T$ be a positive random variable with a pdf $f_T$ then
# the failure rate function is defined by the following:
#
# $$h(t)=\lim_{\epsilon \to 0} \frac{P(t<T \leq t+\epsilon | T>t)}{\epsilon}$$
#
# Equivalently, an object having failure rate function $h$ means that for any $t > 0,$ given
# that the object is still working at time $t$, the probability it will fail in the next
# $\epsilon$ time units is $h(t)\epsilon + o(\epsilon)$.  (As usual, $o(\epsilon)$ represents an error term such that $o(\epsilon)/\epsilon \to 0$ as $\epsilon\to 0.$)  With a little bit more derivation (shown in Section 3.9 of your ECE 313 text), we can see that:
#
# $$h(t) = \frac{f_T(t)}{1-F_T(t)}$$
#
# Of course, the pdf $f_T$ is the derivative of the CDF $F_T$. Here's where your 1D ODE comes into play. Given a failure rate function, we want to be able to calculate the CDF. We can easily turn this into an ODE.
#
# $f_T(t) = (1-F_T(t))h(t)$
#
# Let $F_T(t) = y$ and  $f_T(t) = \frac{dy}{dt} = \dot{y}$, then:
#
# $\dot{y} = (1-y)h(t)$
#
# Now we have our differential equation set up and we can solve it by the same method used in the previous example. For the code below, we define a particular bathtub shaped failure rate function to model the lifetime of a component such as a hard disk drive. There is a high, but decreasing initial rate of failure, followed be a period with a very low rate failure, followed by an increasing rate of failure. You should be able to think of reasons why an object might exhibit this type of failure rate function. Notice that the CDF behaves as we would expect: always between 0 and 1, and reactive to $h(t)$.
#
# If you examine the ECE 313 notes you'll see another way to determine $F_T,$  namely, using
# $F_T(t) = 1- \exp \left( \int_o^t -h(s) ds \right)$.  The point here, though, is to get some practice using
# odeint, instead of using this formula.

# %%
# Calculation of CDF from its failure rate function, using dF/dt=(1-F(t))h(t)
from scipy.integrate import odeint

def h(t):   # h is the failure rate function with a bathtub shape
    if t<1:
        return 1-t
    elif t<3:
        return 0.0
    else:
        return np.sqrt(t-3)
    

def Fdot(y,t):    
    return (1-y)*h(t)

t_max=8.0  #  Select so that F(t_max) is very close to one
time=np.linspace(0.0,t_max,1000)
Finit=0.0
F=odeint(Fdot,Finit,time)

plt.plot(time,list(map(h,time)))
plt.text(4,h(4)+0.5, r'$h(t)$',fontsize=24) #Plots labels in the graph
plt.text(4,0.5, r'$F(t)$',fontsize=24) 

plt.plot(time,F)
plt.title('failure rate function $h$ and associated CDF, $F$')
plt.axis(ymin=0,ymax=2.0)
plt.ylabel('$h(t), F(t)$',fontsize=20)
plt.xlabel('$t$',fontsize=20)
# Out:
# Text(0.5, 0, '$t$')

# %% [markdown]
# **<SPAN style="BACKGROUND-COLOR: #C0C0C0">Problem 1:</SPAN>** Using the information on failure rate functions and the example above, do the following:
# <ol>
# <li> Write code that, given the failure rate function of a random variable $T$, computes the mean lifetime, $E[T].$  Use this code to determine the mean lifetime for the example given above.  (Hint: An easy way to do this problem is to use the area rule for expectations. Since $T$ is nonnegative, the area rule for expectations gives $E[T]=\int_0^\infty(1-F(t)) dt.$
# The integral $\int_0^\infty (1-F(t)) dt$ is approximately equal to
# $\int_0^{t_{max}} (1-F(t)) dt,$  which, by the definition of Riemann integration, is approximately equal to
# $h \sum_{i=1}^{1000} (1-F(h_i)) $ where $h=t_{max}/1000.$  Basically the code above returns the samples $F(h_i)$ so all you need to do is subtract these values from 1, sum them up and multiply by $h$.)
# <li> What happens to $E[T]$ if the failure rate function is doubled for all time? Print out the new value of $E[T]$.
# </ol>

# %%
# Your code here
# part 1 code:
t_max=8.0  #  Select so that F(t_max) is very close to one
time=np.linspace(0.0,t_max,1000)
Finit=0.0
F=odeint(Fdot,Finit,time)
avg = 0
for i in range(len(F)):
    avg += (1-F[i][0])*t_max/1000
print('E[T] = ', avg)

# part 2 code:
def h_2(t):   # h is the failure rate function with a bathtub shape
    if t<1:
        return 2*(1-t)
    elif t<3:
        return 0.0
    else:
        return 2*np.sqrt(t-3)
    

def Fdot_2(y,t):    
    return 2*(1-y)*h_2(t)

F=odeint(Fdot_2,Finit,time)
avg = 0
for i in range(len(F)):
    avg += (1-F[i][0])*t_max/1000
print('E[T] = ', avg, ' for Doubled rate')
# Out:
# E[T] =  2.656524220052051
# E[T] =  0.6575642761393152  for Doubled rate

# %% [markdown]
# __Answer:__ (Your answer here)
#
# The E[T] would decrease as the failure rate doubled.

# %% [markdown]
# **<SPAN style="BACKGROUND-COLOR: #C0C0C0">End of Problem 1</SPAN>**

# %% [markdown]
# ## Evolutionary games (replicator dynamics):

# %% [markdown]
# Consider a population of individuals, where each individual is of some type.  Suppose individuals have occasional pairwise encounters.  During an encounter the two individuals involved play a two player symmetric game in which the strategies are the types of the individuals.   As a result of the encounter, each of the two individuals produces a number of offspring of its same type, with the number being determined by a fitess table or, equivalently, a fitness matrix.   For example, consider a population of crickets such that each cricket is either small or large.   If two small crickets meet each other then they each spawn five more small crickets.  If a small cricket encounters a large cricket then the small cricket spawns one more small cricket and the large cricket spawns eight new large crickets.   If two large crickets meet then each of them spawns three new large crickets.  We can summarize these outcomes using the following table:
# $$\begin{array}{c|cc}  & small & large  \\ \hline
#     small & 5 & 1  \\
#     large & 8 & 3
#     \end{array}$$
# or by a fitness matrix
# $$F=\left( \begin{array}{cc}  5 & 1 \\ 8 & 3  \end{array}\right).$$
# Associating 0 with "small" and 1 with "large,"  we see that if a type i individual encounters a type j individual, then the type i individual spawns F[i,j] new individuals of type i, and the type j individual spawns F[j,i] new individuals of type j. Below is a stochastic simulation for this game where we start with a population of four small crickets and four large crickets. It may be a useful exercise for you to think of how the values for $a$ and $b$ were created.

# %%
# Stochastic simulation of replicator dynamics for cricket game

F=np.array([[5,1],[8,3]])  # fitness matrix

n=np.array([4,4])  #[number of small crickets, number of large crickets], initialized
print ("                                   State      Fractions of each type")
print ("Initially                        ", n, "      ", n/1./np.sum(n))

T = 100 #total number of encounters

for k in range(T):   # k tracks number of encounters
    a=n[0]*(n[0]-1.0)/((n[0]+n[1])*(n[0]+n[1]-1))  # probability both players are type 0
    b=2*n[0]*n[1]/((n[0]+n[1])*(n[0]+n[1]-1.0))  # probability one player of each type
    U=np.random.rand()
    if U<=a:
        n+=[2*F[0,0],0]
        print ("Round",k+1,"two small crickets meet ", n, n/1./np.sum(n))
    elif a<U<=a+b:
        n+=[F[0,1],F[1,0]]
        print ("Round",k+1,"a small meets a large   ", n, n/1./np.sum(n))
    else:
        n+=[0,2*F[1,1]]
        print ("Round",k+1,"two large crickets meet ", n, n/1./np.sum(n))
# Out:
#                                    State      Fractions of each type
# Initially                         [4 4]        [0.5 0.5]
# Round 1 two large crickets meet  [ 4 10] [0.28571429 0.71428571]
# Round 2 two large crickets meet  [ 4 16] [0.2 0.8]
# Round 3 two large crickets meet  [ 4 22] [0.15384615 0.84615385]
# Round 4 two large crickets meet  [ 4 28] [0.125 0.875]
# Round 5 two large crickets meet  [ 4 34] [0.10526316 0.89473684]
# Round 6 two large crickets meet  [ 4 40] [0.09090909 0.90909091]
# Round 7 two large crickets meet  [ 4 46] [0.08 0.92]
# Round 8 two large crickets meet  [ 4 52] [0.07142857 0.92857143]
# Round 9 two large crickets meet  [ 4 58] [0.06451613 0.93548387]
# Round 10 two large crickets meet  [ 4 64] [0.05882353 0.94117647]
# Round 11 two large crickets meet  [ 4 70] [0.05405405 0.94594595]
# Round 12 two large crickets meet  [ 4 76] [0.05 0.95]
# Round 13 two large crickets meet  [ 4 82] [0.04651163 0.95348837]
# Round 14 two large crickets meet  [ 4 88] [0.04347826 0.95652174]
# Round 15 two large crickets meet  [ 4 94] [0.04081633 0.95918367]
# Round 16 a small meets a large    [  5 102] [0.04672897 0.95327103]
# Round 17 two large crickets meet  [  5 108] [0.04424779 0.95575221]
# Round 18 two large crickets meet  [  5 114] [0.04201681 0.95798319]
# Round 19 two large crickets meet  [  5 120] [0.04 0.96]
# Round 20 a small meets a large    [  6 128] [0.04477612 0.95522388]
# Round 21 two large crickets meet  [  6 134] [0.04285714 0.95714286]
# Round 22 two large crickets meet  [  6 140] [0.04109589 0.95890411]
# Round 23 two large crickets meet  [  6 146] [0.03947368 0.96052632]
# Round 24 two large crickets meet  [  6 152] [0.03797468 0.96202532]
# Round 25 two large crickets meet  [  6 158] [0.03658537 0.96341463]
# Round 26 two large crickets meet  [  6 164] [0.03529412 0.96470588]
# Round 27 a small meets a large    [  7 172] [0.03910615 0.96089385]
# Round 28 two large crickets meet  [  7 178] [0.03783784 0.96216216]
# Round 29 two large crickets meet  [  7 184] [0.03664921 0.96335079]
# Round 30 two large crickets meet  [  7 190] [0.03553299 0.96446701]
# Round 31 two large crickets meet  [  7 196] [0.03448276 0.96551724]
# Round 32 two large crickets meet  [  7 202] [0.03349282 0.96650718]
# Round 33 two large crickets meet  [  7 208] [0.03255814 0.96744186]
# Round 34 two large crickets meet  [  7 214] [0.03167421 0.96832579]
# Round 35 two large crickets meet  [  7 220] [0.030837 0.969163]
# Round 36 two large crickets meet  [  7 226] [0.03004292 0.96995708]
# Round 37 two large crickets meet  [  7 232] [0.0292887 0.9707113]
# Round 38 a small meets a large    [  8 240] [0.03225806 0.96774194]
# Round 39 two large crickets meet  [  8 246] [0.03149606 0.96850394]
# Round 40 two large crickets meet  [  8 252] [0.03076923 0.96923077]
# Round 41 two large crickets meet  [  8 258] [0.03007519 0.96992481]
# Round 42 two large crickets meet  [  8 264] [0.02941176 0.97058824]
# Round 43 two large crickets meet  [  8 270] [0.02877698 0.97122302]
# Round 44 two large crickets meet  [  8 276] [0.02816901 0.97183099]
# Round 45 two large crickets meet  [  8 282] [0.02758621 0.97241379]
# Round 46 a small meets a large    [  9 290] [0.03010033 0.96989967]
# Round 47 two large crickets meet  [  9 296] [0.0295082 0.9704918]
# Round 48 two large crickets meet  [  9 302] [0.02893891 0.97106109]
# Round 49 two large crickets meet  [  9 308] [0.02839117 0.97160883]
# Round 50 two large crickets meet  [  9 314] [0.02786378 0.97213622]
# Round 51 two large crickets meet  [  9 320] [0.02735562 0.97264438]
# Round 52 two large crickets meet  [  9 326] [0.02686567 0.97313433]
# Round 53 two large crickets meet  [  9 332] [0.02639296 0.97360704]
# Round 54 two large crickets meet  [  9 338] [0.0259366 0.9740634]
# Round 55 two large crickets meet  [  9 344] [0.02549575 0.97450425]
# Round 56 two large crickets meet  [  9 350] [0.02506964 0.97493036]
# Round 57 two large crickets meet  [  9 356] [0.02465753 0.97534247]
# Round 58 two large crickets meet  [  9 362] [0.02425876 0.97574124]
# Round 59 two large crickets meet  [  9 368] [0.02387268 0.97612732]
# Round 60 two large crickets meet  [  9 374] [0.02349869 0.97650131]
# Round 61 two large crickets meet  [  9 380] [0.02313625 0.97686375]
# Round 62 two large crickets meet  [  9 386] [0.02278481 0.97721519]
# Round 63 two large crickets meet  [  9 392] [0.02244389 0.97755611]
# Round 64 two large crickets meet  [  9 398] [0.02211302 0.97788698]
# Round 65 two large crickets meet  [  9 404] [0.02179177 0.97820823]
# Round 66 two large crickets meet  [  9 410] [0.02147971 0.97852029]
# Round 67 two large crickets meet  [  9 416] [0.02117647 0.97882353]
# Round 68 two large crickets meet  [  9 422] [0.02088167 0.97911833]
# Round 69 two large crickets meet  [  9 428] [0.02059497 0.97940503]
# Round 70 two large crickets meet  [  9 434] [0.02031603 0.97968397]
# Round 71 two large crickets meet  [  9 440] [0.02004454 0.97995546]
# Round 72 two large crickets meet  [  9 446] [0.01978022 0.98021978]
# Round 73 two large crickets meet  [  9 452] [0.01952278 0.98047722]
# Round 74 two large crickets meet  [  9 458] [0.01927195 0.98072805]
# Round 75 two large crickets meet  [  9 464] [0.01902748 0.98097252]
# Round 76 two large crickets meet  [  9 470] [0.01878914 0.98121086]
# Round 77 two large crickets meet  [  9 476] [0.0185567 0.9814433]
# Round 78 two large crickets meet  [  9 482] [0.01832994 0.98167006]
# Round 79 two large crickets meet  [  9 488] [0.01810865 0.98189135]
# Round 80 two large crickets meet  [  9 494] [0.01789264 0.98210736]
# Round 81 two large crickets meet  [  9 500] [0.01768173 0.98231827]
# Round 82 two large crickets meet  [  9 506] [0.01747573 0.98252427]
# Round 83 two large crickets meet  [  9 512] [0.01727447 0.98272553]
# Round 84 two large crickets meet  [  9 518] [0.0170778 0.9829222]
# Round 85 two large crickets meet  [  9 524] [0.01688555 0.98311445]
# Round 86 a small meets a large    [ 10 532] [0.01845018 0.98154982]
# Round 87 two large crickets meet  [ 10 538] [0.01824818 0.98175182]
# Round 88 two large crickets meet  [ 10 544] [0.01805054 0.98194946]
# Round 89 two large crickets meet  [ 10 550] [0.01785714 0.98214286]
# Round 90 two large crickets meet  [ 10 556] [0.01766784 0.98233216]
# Round 91 two large crickets meet  [ 10 562] [0.01748252 0.98251748]
# Round 92 two large crickets meet  [ 10 568] [0.01730104 0.98269896]
# Round 93 two large crickets meet  [ 10 574] [0.01712329 0.98287671]
# Round 94 two large crickets meet  [ 10 580] [0.01694915 0.98305085]
# Round 95 two large crickets meet  [ 10 586] [0.01677852 0.98322148]
# Round 96 two large crickets meet  [ 10 592] [0.0166113 0.9833887]
# Round 97 two large crickets meet  [ 10 598] [0.01644737 0.98355263]
# Round 98 two large crickets meet  [ 10 604] [0.01628664 0.98371336]
# Round 99 two large crickets meet  [ 10 610] [0.01612903 0.98387097]
# Round 100 two large crickets meet  [ 10 616] [0.01597444 0.98402556]

# %%
n=np.array([10,1])  #[number of small crickets, number of large crickets], initialized
print ("                                   State      Fractions of each type")
print ("Initially                        ", n, "      ", n/1./np.sum(n))

T = 100 #total number of encounters

for k in range(T):   # k tracks number of encounters
    a=n[0]*(n[0]-1.0)/((n[0]+n[1])*(n[0]+n[1]-1))  # probability both players are type 0
    b=2*n[0]*n[1]/((n[0]+n[1])*(n[0]+n[1]-1.0))  # probability one player of each type
    U=np.random.rand()
    if U<=a:
        n+=[2*F[0,0],0]
        print ("Round",k+1,"two small crickets meet ", n, n/1./np.sum(n))
    elif a<U<=a+b:
        n+=[F[0,1],F[1,0]]
        print ("Round",k+1,"a small meets a large   ", n, n/1./np.sum(n))
    else:
        n+=[0,2*F[1,1]]
        print ("Round",k+1,"two large crickets meet ", n, n/1./np.sum(n))
# Out:
#                                    State      Fractions of each type
# Initially                         [10  1]        [0.90909091 0.09090909]
# Round 1 two small crickets meet  [20  1] [0.95238095 0.04761905]
# Round 2 two small crickets meet  [30  1] [0.96774194 0.03225806]
# Round 3 two small crickets meet  [40  1] [0.97560976 0.02439024]
# Round 4 two small crickets meet  [50  1] [0.98039216 0.01960784]
# Round 5 two small crickets meet  [60  1] [0.98360656 0.01639344]
# Round 6 two small crickets meet  [70  1] [0.98591549 0.01408451]
# Round 7 two small crickets meet  [80  1] [0.98765432 0.01234568]
# Round 8 two small crickets meet  [90  1] [0.98901099 0.01098901]
# Round 9 two small crickets meet  [100   1] [0.99009901 0.00990099]
# Round 10 two small crickets meet  [110   1] [0.99099099 0.00900901]
# Round 11 two small crickets meet  [120   1] [0.99173554 0.00826446]
# Round 12 two small crickets meet  [130   1] [0.99236641 0.00763359]
# Round 13 two small crickets meet  [140   1] [0.9929078 0.0070922]
# Round 14 two small crickets meet  [150   1] [0.99337748 0.00662252]
# Round 15 two small crickets meet  [160   1] [0.99378882 0.00621118]
# Round 16 two small crickets meet  [170   1] [0.99415205 0.00584795]
# Round 17 two small crickets meet  [180   1] [0.99447514 0.00552486]
# Round 18 two small crickets meet  [190   1] [0.9947644 0.0052356]
# Round 19 two small crickets meet  [200   1] [0.99502488 0.00497512]
# Round 20 two small crickets meet  [210   1] [0.99526066 0.00473934]
# Round 21 two small crickets meet  [220   1] [0.99547511 0.00452489]
# Round 22 two small crickets meet  [230   1] [0.995671 0.004329]
# Round 23 two small crickets meet  [240   1] [0.99585062 0.00414938]
# Round 24 two small crickets meet  [250   1] [0.99601594 0.00398406]
# Round 25 two small crickets meet  [260   1] [0.99616858 0.00383142]
# Round 26 two small crickets meet  [270   1] [0.99630996 0.00369004]
# Round 27 two small crickets meet  [280   1] [0.99644128 0.00355872]
# Round 28 two small crickets meet  [290   1] [0.99656357 0.00343643]
# Round 29 two small crickets meet  [300   1] [0.99667774 0.00332226]
# Round 30 two small crickets meet  [310   1] [0.99678457 0.00321543]
# Round 31 two small crickets meet  [320   1] [0.99688474 0.00311526]
# Round 32 two small crickets meet  [330   1] [0.99697885 0.00302115]
# Round 33 two small crickets meet  [340   1] [0.99706745 0.00293255]
# Round 34 two small crickets meet  [350   1] [0.997151 0.002849]
# Round 35 two small crickets meet  [360   1] [0.99722992 0.00277008]
# Round 36 two small crickets meet  [370   1] [0.99730458 0.00269542]
# Round 37 a small meets a large    [371   9] [0.97631579 0.02368421]
# Round 38 two small crickets meet  [381   9] [0.97692308 0.02307692]
# Round 39 a small meets a large    [382  17] [0.95739348 0.04260652]
# Round 40 two small crickets meet  [392  17] [0.95843521 0.04156479]
# Round 41 two small crickets meet  [402  17] [0.95942721 0.04057279]
# Round 42 two small crickets meet  [412  17] [0.96037296 0.03962704]
# Round 43 two small crickets meet  [422  17] [0.96127563 0.03872437]
# Round 44 two small crickets meet  [432  17] [0.96213808 0.03786192]
# Round 45 two small crickets meet  [442  17] [0.96296296 0.03703704]
# Round 46 two small crickets meet  [452  17] [0.96375267 0.03624733]
# Round 47 two small crickets meet  [462  17] [0.96450939 0.03549061]
# Round 48 two small crickets meet  [472  17] [0.96523517 0.03476483]
# Round 49 two small crickets meet  [482  17] [0.96593186 0.03406814]
# Round 50 two small crickets meet  [492  17] [0.96660118 0.03339882]
# Round 51 two small crickets meet  [502  17] [0.9672447 0.0327553]
# Round 52 two small crickets meet  [512  17] [0.96786389 0.03213611]
# Round 53 two small crickets meet  [522  17] [0.96846011 0.03153989]
# Round 54 two small crickets meet  [532  17] [0.96903461 0.03096539]
# Round 55 two small crickets meet  [542  17] [0.96958855 0.03041145]
# Round 56 two small crickets meet  [552  17] [0.97012302 0.02987698]
# Round 57 two small crickets meet  [562  17] [0.97063903 0.02936097]
# Round 58 a small meets a large    [563  25] [0.95748299 0.04251701]
# Round 59 two small crickets meet  [573  25] [0.95819398 0.04180602]
# Round 60 two small crickets meet  [583  25] [0.95888158 0.04111842]
# Round 61 two small crickets meet  [593  25] [0.95954693 0.04045307]
# Round 62 two small crickets meet  [603  25] [0.96019108 0.03980892]
# Round 63 two small crickets meet  [613  25] [0.96081505 0.03918495]
# Round 64 two small crickets meet  [623  25] [0.96141975 0.03858025]
# Round 65 two small crickets meet  [633  25] [0.96200608 0.03799392]
# Round 66 two small crickets meet  [643  25] [0.96257485 0.03742515]
# Round 67 two small crickets meet  [653  25] [0.96312684 0.03687316]
# Round 68 two small crickets meet  [663  25] [0.96366279 0.03633721]
# Round 69 a small meets a large    [664  33] [0.95265423 0.04734577]
# Round 70 two small crickets meet  [674  33] [0.9533239 0.0466761]
# Round 71 two small crickets meet  [684  33] [0.9539749 0.0460251]
# Round 72 two small crickets meet  [694  33] [0.95460798 0.04539202]
# Round 73 two small crickets meet  [704  33] [0.95522388 0.04477612]
# Round 74 two small crickets meet  [714  33] [0.95582329 0.04417671]
# Round 75 two small crickets meet  [724  33] [0.95640687 0.04359313]
# Round 76 two small crickets meet  [734  33] [0.95697523 0.04302477]
# Round 77 two small crickets meet  [744  33] [0.95752896 0.04247104]
# Round 78 two small crickets meet  [754  33] [0.95806861 0.04193139]
# Round 79 two small crickets meet  [764  33] [0.95859473 0.04140527]
# Round 80 two small crickets meet  [774  33] [0.95910781 0.04089219]
# Round 81 two small crickets meet  [784  33] [0.95960832 0.04039168]
# Round 82 two small crickets meet  [794  33] [0.96009674 0.03990326]
# Round 83 two small crickets meet  [804  33] [0.96057348 0.03942652]
# Round 84 two small crickets meet  [814  33] [0.96103896 0.03896104]
# Round 85 two small crickets meet  [824  33] [0.96149358 0.03850642]
# Round 86 two small crickets meet  [834  33] [0.96193772 0.03806228]
# Round 87 two small crickets meet  [844  33] [0.96237172 0.03762828]
# Round 88 two small crickets meet  [854  33] [0.96279594 0.03720406]
# Round 89 two small crickets meet  [864  33] [0.9632107 0.0367893]
# Round 90 two small crickets meet  [874  33] [0.96361632 0.03638368]
# Round 91 two small crickets meet  [884  33] [0.96401309 0.03598691]
# Round 92 two small crickets meet  [894  33] [0.96440129 0.03559871]
# Round 93 two small crickets meet  [904  33] [0.96478122 0.03521878]
# Round 94 two small crickets meet  [914  33] [0.96515312 0.03484688]
# Round 95 two small crickets meet  [924  33] [0.96551724 0.03448276]
# Round 96 two small crickets meet  [934  33] [0.96587384 0.03412616]
# Round 97 two small crickets meet  [944  33] [0.96622313 0.03377687]
# Round 98 two small crickets meet  [954  33] [0.96656535 0.03343465]
# Round 99 two small crickets meet  [964  33] [0.9669007 0.0330993]
# Round 100 two small crickets meet  [974  33] [0.96722939 0.03277061]

# %%
n=np.array([0,8])  #[number of small crickets, number of large crickets], initialized
print ("                                   State      Fractions of each type")
print ("Initially                        ", n, "      ", n/1./np.sum(n))

T = 100 #total number of encounters

for k in range(T):   # k tracks number of encounters
    a=n[0]*(n[0]-1.0)/((n[0]+n[1])*(n[0]+n[1]-1))  # probability both players are type 0
    b=2*n[0]*n[1]/((n[0]+n[1])*(n[0]+n[1]-1.0))  # probability one player of each type
    U=np.random.rand()
    if U<=a:
        n+=[2*F[0,0],0]
        print ("Round",k+1,"two small crickets meet ", n, n/1./np.sum(n))
    elif a<U<=a+b:
        n+=[F[0,1],F[1,0]]
        print ("Round",k+1,"a small meets a large   ", n, n/1./np.sum(n))
    else:
        n+=[0,2*F[1,1]]
        print ("Round",k+1,"two large crickets meet ", n, n/1./np.sum(n))
# Out:
#                                    State      Fractions of each type
# Initially                         [0 8]        [0. 1.]
# Round 1 two large crickets meet  [ 0 14] [0. 1.]
# Round 2 two large crickets meet  [ 0 20] [0. 1.]
# Round 3 two large crickets meet  [ 0 26] [0. 1.]
# Round 4 two large crickets meet  [ 0 32] [0. 1.]
# Round 5 two large crickets meet  [ 0 38] [0. 1.]
# Round 6 two large crickets meet  [ 0 44] [0. 1.]
# Round 7 two large crickets meet  [ 0 50] [0. 1.]
# Round 8 two large crickets meet  [ 0 56] [0. 1.]
# Round 9 two large crickets meet  [ 0 62] [0. 1.]
# Round 10 two large crickets meet  [ 0 68] [0. 1.]
# Round 11 two large crickets meet  [ 0 74] [0. 1.]
# Round 12 two large crickets meet  [ 0 80] [0. 1.]
# Round 13 two large crickets meet  [ 0 86] [0. 1.]
# Round 14 two large crickets meet  [ 0 92] [0. 1.]
# Round 15 two large crickets meet  [ 0 98] [0. 1.]
# Round 16 two large crickets meet  [  0 104] [0. 1.]
# Round 17 two large crickets meet  [  0 110] [0. 1.]
# Round 18 two large crickets meet  [  0 116] [0. 1.]
# Round 19 two large crickets meet  [  0 122] [0. 1.]
# Round 20 two large crickets meet  [  0 128] [0. 1.]
# Round 21 two large crickets meet  [  0 134] [0. 1.]
# Round 22 two large crickets meet  [  0 140] [0. 1.]
# Round 23 two large crickets meet  [  0 146] [0. 1.]
# Round 24 two large crickets meet  [  0 152] [0. 1.]
# Round 25 two large crickets meet  [  0 158] [0. 1.]
# Round 26 two large crickets meet  [  0 164] [0. 1.]
# Round 27 two large crickets meet  [  0 170] [0. 1.]
# Round 28 two large crickets meet  [  0 176] [0. 1.]
# Round 29 two large crickets meet  [  0 182] [0. 1.]
# Round 30 two large crickets meet  [  0 188] [0. 1.]
# Round 31 two large crickets meet  [  0 194] [0. 1.]
# Round 32 two large crickets meet  [  0 200] [0. 1.]
# Round 33 two large crickets meet  [  0 206] [0. 1.]
# Round 34 two large crickets meet  [  0 212] [0. 1.]
# Round 35 two large crickets meet  [  0 218] [0. 1.]
# Round 36 two large crickets meet  [  0 224] [0. 1.]
# Round 37 two large crickets meet  [  0 230] [0. 1.]
# Round 38 two large crickets meet  [  0 236] [0. 1.]
# Round 39 two large crickets meet  [  0 242] [0. 1.]
# Round 40 two large crickets meet  [  0 248] [0. 1.]
# Round 41 two large crickets meet  [  0 254] [0. 1.]
# Round 42 two large crickets meet  [  0 260] [0. 1.]
# Round 43 two large crickets meet  [  0 266] [0. 1.]
# Round 44 two large crickets meet  [  0 272] [0. 1.]
# Round 45 two large crickets meet  [  0 278] [0. 1.]
# Round 46 two large crickets meet  [  0 284] [0. 1.]
# Round 47 two large crickets meet  [  0 290] [0. 1.]
# Round 48 two large crickets meet  [  0 296] [0. 1.]
# Round 49 two large crickets meet  [  0 302] [0. 1.]
# Round 50 two large crickets meet  [  0 308] [0. 1.]
# Round 51 two large crickets meet  [  0 314] [0. 1.]
# Round 52 two large crickets meet  [  0 320] [0. 1.]
# Round 53 two large crickets meet  [  0 326] [0. 1.]
# Round 54 two large crickets meet  [  0 332] [0. 1.]
# Round 55 two large crickets meet  [  0 338] [0. 1.]
# Round 56 two large crickets meet  [  0 344] [0. 1.]
# Round 57 two large crickets meet  [  0 350] [0. 1.]
# Round 58 two large crickets meet  [  0 356] [0. 1.]
# Round 59 two large crickets meet  [  0 362] [0. 1.]
# Round 60 two large crickets meet  [  0 368] [0. 1.]
# Round 61 two large crickets meet  [  0 374] [0. 1.]
# Round 62 two large crickets meet  [  0 380] [0. 1.]
# Round 63 two large crickets meet  [  0 386] [0. 1.]
# Round 64 two large crickets meet  [  0 392] [0. 1.]
# Round 65 two large crickets meet  [  0 398] [0. 1.]
# Round 66 two large crickets meet  [  0 404] [0. 1.]
# Round 67 two large crickets meet  [  0 410] [0. 1.]
# Round 68 two large crickets meet  [  0 416] [0. 1.]
# Round 69 two large crickets meet  [  0 422] [0. 1.]
# Round 70 two large crickets meet  [  0 428] [0. 1.]
# Round 71 two large crickets meet  [  0 434] [0. 1.]
# Round 72 two large crickets meet  [  0 440] [0. 1.]
# Round 73 two large crickets meet  [  0 446] [0. 1.]
# Round 74 two large crickets meet  [  0 452] [0. 1.]
# Round 75 two large crickets meet  [  0 458] [0. 1.]
# Round 76 two large crickets meet  [  0 464] [0. 1.]
# Round 77 two large crickets meet  [  0 470] [0. 1.]
# Round 78 two large crickets meet  [  0 476] [0. 1.]
# Round 79 two large crickets meet  [  0 482] [0. 1.]
# Round 80 two large crickets meet  [  0 488] [0. 1.]
# Round 81 two large crickets meet  [  0 494] [0. 1.]
# Round 82 two large crickets meet  [  0 500] [0. 1.]
# Round 83 two large crickets meet  [  0 506] [0. 1.]
# Round 84 two large crickets meet  [  0 512] [0. 1.]
# Round 85 two large crickets meet  [  0 518] [0. 1.]
# Round 86 two large crickets meet  [  0 524] [0. 1.]
# Round 87 two large crickets meet  [  0 530] [0. 1.]
# Round 88 two large crickets meet  [  0 536] [0. 1.]
# Round 89 two large crickets meet  [  0 542] [0. 1.]
# Round 90 two large crickets meet  [  0 548] [0. 1.]
# Round 91 two large crickets meet  [  0 554] [0. 1.]
# Round 92 two large crickets meet  [  0 560] [0. 1.]
# Round 93 two large crickets meet  [  0 566] [0. 1.]
# Round 94 two large crickets meet  [  0 572] [0. 1.]
# Round 95 two large crickets meet  [  0 578] [0. 1.]
# Round 96 two large crickets meet  [  0 584] [0. 1.]
# Round 97 two large crickets meet  [  0 590] [0. 1.]
# Round 98 two large crickets meet  [  0 596] [0. 1.]
# Round 99 two large crickets meet  [  0 602] [0. 1.]
# Round 100 two large crickets meet  [  0 608] [0. 1.]

# %%
n=np.array([4,4])  #[number of small crickets, number of large crickets], initialized
print ("                                   State      Fractions of each type")
print ("Initially                        ", n, "      ", n/1./np.sum(n))

T = 10000 #total number of encounters

for k in range(T):   # k tracks number of encounters
    a=n[0]*(n[0]-1.0)/((n[0]+n[1])*(n[0]+n[1]-1))  # probability both players are type 0
    b=2*n[0]*n[1]/((n[0]+n[1])*(n[0]+n[1]-1.0))  # probability one player of each type
    U=np.random.rand()
    if U<=a:
        n+=[2*F[0,0],0]
    elif a<U<=a+b:
        n+=[F[0,1],F[1,0]]
    else:
        n+=[0,2*F[1,1]]
    if (k+1)%100 == 0:    
        print ("Round",k+1, 'Total number', n, n/1./np.sum(n))
# Out:
#                                    State      Fractions of each type
# Initially                         [4 4]        [0.5 0.5]
# Round 100 Total number [  8 612] [0.01290323 0.98709677]
# Round 200 Total number [   9 1214] [0.00735895 0.99264105]
# Round 300 Total number [  10 1816] [0.00547645 0.99452355]
# Round 400 Total number [  12 2420] [0.00493421 0.99506579]
# Round 500 Total number [  12 3020] [0.00395778 0.99604222]
# Round 600 Total number [  14 3624] [0.00384827 0.99615173]
# Round 700 Total number [  15 4226] [0.0035369 0.9964631]
# Round 800 Total number [  15 4826] [0.00309853 0.99690147]
# Round 900 Total number [  16 5428] [0.00293902 0.99706098]
# Round 1000 Total number [  16 6028] [0.00264725 0.99735275]
# Round 1100 Total number [  16 6628] [0.00240819 0.99759181]
# Round 1200 Total number [  17 7230] [0.0023458 0.9976542]
# Round 1300 Total number [  18 7832] [0.00229299 0.99770701]
# Round 1400 Total number [  18 8432] [0.00213018 0.99786982]
# Round 1500 Total number [  18 9032] [0.00198895 0.99801105]
# Round 1600 Total number [  18 9632] [0.00186528 0.99813472]
# Round 1700 Total number [   18 10232] [0.0017561 0.9982439]
# Round 1800 Total number [   18 10832] [0.00165899 0.99834101]
# Round 1900 Total number [   18 11432] [0.00157205 0.99842795]
# Round 2000 Total number [   18 12032] [0.00149378 0.99850622]
# Round 2100 Total number [   18 12632] [0.00142292 0.99857708]
# Round 2200 Total number [   18 13232] [0.00135849 0.99864151]
# Round 2300 Total number [   18 13832] [0.00129964 0.99870036]
# Round 2400 Total number [   18 14432] [0.00124567 0.99875433]
# Round 2500 Total number [   18 15032] [0.00119601 0.99880399]
# Round 2600 Total number [   18 15632] [0.00115016 0.99884984]
# Round 2700 Total number [   18 16232] [0.00110769 0.99889231]
# Round 2800 Total number [   19 16834] [0.0011274 0.9988726]
# Round 2900 Total number [   19 17434] [0.00108864 0.99891136]
# Round 3000 Total number [   19 18034] [0.00105246 0.99894754]
# Round 3100 Total number [   19 18634] [0.0010186 0.9989814]
# Round 3200 Total number [   20 19236] [0.00103864 0.99896136]
# Round 3300 Total number [   20 19836] [0.00100725 0.99899275]
# Round 3400 Total number [   21 20438] [0.00102644 0.99897356]
# Round 3500 Total number [   21 21038] [9.97198347e-04 9.99002802e-01]
# Round 3600 Total number [   21 21638] [9.69573849e-04 9.99030426e-01]
# Round 3700 Total number [   21 22238] [9.43438609e-04 9.99056561e-01]
# Round 3800 Total number [   21 22838] [9.18675358e-04 9.99081325e-01]
# Round 3900 Total number [   21 23438] [8.95178823e-04 9.99104821e-01]
# Round 4000 Total number [   21 24038] [8.72854233e-04 9.99127146e-01]
# Round 4100 Total number [   22 24640] [8.92060660e-04 9.99107939e-01]
# Round 4200 Total number [   22 25240] [8.70873248e-04 9.99129127e-01]
# Round 4300 Total number [   23 25842] [8.89232554e-04 9.99110767e-01]
# Round 4400 Total number [   24 26444] [9.06755327e-04 9.99093245e-01]
# Round 4500 Total number [   24 27044] [8.86655830e-04 9.99113344e-01]
# Round 4600 Total number [   25 27646] [9.03472950e-04 9.99096527e-01]
# Round 4700 Total number [   25 28246] [8.84298398e-04 9.99115702e-01]
# Round 4800 Total number [   25 28846] [8.65920820e-04 9.99134079e-01]
# Round 4900 Total number [   26 29448] [8.82133406e-04 9.99117867e-01]
# Round 5000 Total number [   26 30048] [8.64534149e-04 9.99135466e-01]
# Round 5100 Total number [   26 30648] [8.47623394e-04 9.99152377e-01]
# Round 5200 Total number [   27 31250] [8.63254148e-04 9.99136746e-01]
# Round 5300 Total number [   27 31850] [8.47005678e-04 9.99152994e-01]
# Round 5400 Total number [   27 32450] [8.31357576e-04 9.99168642e-01]
# Round 5500 Total number [   27 33050] [8.16277171e-04 9.99183723e-01]
# Round 5600 Total number [   27 33650] [8.01734121e-04 9.99198266e-01]
# Round 5700 Total number [   27 34250] [7.87700207e-04 9.99212300e-01]
# Round 5800 Total number [   27 34850] [7.74149153e-04 9.99225851e-01]
# Round 5900 Total number [   28 35452] [7.89177001e-04 9.99210823e-01]
# Round 6000 Total number [   28 36052] [7.76053215e-04 9.99223947e-01]
# Round 6100 Total number [   28 36652] [7.63358779e-04 9.99236641e-01]
# Round 6200 Total number [   28 37252] [7.51072961e-04 9.99248927e-01]
# Round 6300 Total number [   28 37852] [7.39176346e-04 9.99260824e-01]
# Round 6400 Total number [   28 38452] [7.27650728e-04 9.99272349e-01]
# Round 6500 Total number [   29 39054] [7.42010593e-04 9.99257989e-01]
# Round 6600 Total number [   29 39654] [7.30791523e-04 9.99269208e-01]
# Round 6700 Total number [   29 40254] [7.19906660e-04 9.99280093e-01]
# Round 6800 Total number [   30 40856] [7.33747493e-04 9.99266253e-01]
# Round 6900 Total number [   30 41456] [7.23135516e-04 9.99276864e-01]
# Round 7000 Total number [   30 42056] [7.12826118e-04 9.99287174e-01]
# Round 7100 Total number [   31 42658] [7.26182389e-04 9.99273818e-01]
# Round 7200 Total number [   31 43258] [7.16117258e-04 9.99283883e-01]
# Round 7300 Total number [   31 43858] [7.06327326e-04 9.99293673e-01]
# Round 7400 Total number [   31 44458] [6.96801457e-04 9.99303199e-01]
# Round 7500 Total number [   31 45058] [6.87529109e-04 9.99312471e-01]
# Round 7600 Total number [   31 45658] [6.78500295e-04 9.99321500e-01]
# Round 7700 Total number [   31 46258] [6.69705546e-04 9.99330294e-01]
# Round 7800 Total number [   31 46858] [6.61135874e-04 9.99338864e-01]
# Round 7900 Total number [   31 47458] [6.52782750e-04 9.99347217e-01]
# Round 8000 Total number [   31 48058] [6.44638067e-04 9.99355362e-01]
# Round 8100 Total number [   31 48658] [6.36694120e-04 9.99363306e-01]
# Round 8200 Total number [   31 49258] [6.28943578e-04 9.99371056e-01]
# Round 8300 Total number [   31 49858] [6.21379462e-04 9.99378621e-01]
# Round 8400 Total number [   31 50458] [6.13995128e-04 9.99386005e-01]
# Round 8500 Total number [   32 51060] [6.26321146e-04 9.99373679e-01]
# Round 8600 Total number [   32 51660] [6.19051304e-04 9.99380949e-01]
# Round 8700 Total number [   32 52260] [6.11948290e-04 9.99388052e-01]
# Round 8800 Total number [   32 52860] [6.05006428e-04 9.99394994e-01]
# Round 8900 Total number [   32 53460] [5.98220295e-04 9.99401780e-01]
# Round 9000 Total number [   32 54060] [5.91584708e-04 9.99408415e-01]
# Round 9100 Total number [   32 54660] [5.85094712e-04 9.99414905e-01]
# Round 9200 Total number [   32 55260] [5.78745569e-04 9.99421254e-01]
# Round 9300 Total number [   32 55860] [5.72532742e-04 9.99427467e-01]
# Round 9400 Total number [   32 56460] [5.66451887e-04 9.99433548e-01]
# Round 9500 Total number [   32 57060] [5.60498844e-04 9.99439501e-01]
# Round 9600 Total number [   32 57660] [5.54669625e-04 9.99445330e-01]
# Round 9700 Total number [   32 58260] [5.48960406e-04 9.99451040e-01]
# Round 9800 Total number [   32 58860] [5.43367520e-04 9.99456632e-01]
# Round 9900 Total number [   32 59460] [5.37887447e-04 9.99462113e-01]
# Round 10000 Total number [   32 60060] [5.32516808e-04 9.99467483e-01]

# %% [markdown]
# The above simulation displays, after each encounter, the number of individuals of each type and the fraction of individuals of each type.   Run the simulation multiple times for different initial conditions.
# <br>**<SPAN style="BACKGROUND-COLOR: #C0C0C0">Problem 2:</SPAN>**  Answer the following questions.   You do not need to provide code for this problem, but explain your answers.
# <ol>
# <li> How quickly does the total population grow if initally all the crickets are small?
# <li> How quickly does the total population grow if initally all the crickets are large?
# <li> Do the fractions converge to a stable equilibrium in which the fractions of both small and large crickets are nonzero? (To explore convergence you may need to increase the number of encounters simulated.)
# </ol>

# %% [markdown]
# __Answer:__ (Your answer here)
#
# <li> The total population growth at the 100th time is 1008, it is very quick.
# <li> The total population growth at the 100th time is 608. Relatively slower than the total small crickets.
# <li> Acutally the fraction would not converge, the majority of cricket, which is the large cricket, would get to larger and larger fraction. BUt we can also say that large cricket would be converged to 0

# %% [markdown]
# **<SPAN style="BACKGROUND-COLOR: #C0C0C0">End of Problem 2</SPAN>**

# %% [markdown]
# The code given next is essentially the same as above.  One difference is a time variable is added such that the average rate that an individual cricket has encounters is proportional to the total number of crickets.  This results in exponential growth of the population with time.    Another difference is that population sizes are saved and plotted.

# %%
# Stochastic simulation of replicator dynamics for cricket game
# Time is scaled so contact rate of each individual is one per unit time
# The evolution trajectory is stored an plotted

F=np.array([[5,1],[8,3]])  # fitness matrix
n_max=100  # maximum number of interactions
n=np.zeros((n_max,2),dtype=float)
time=np.zeros(n_max,dtype=float)

n[0,0], n[0,1] = 4,4 # initial [number of small crickets, number of large crickets]

for k in range(n_max-1):
    time[k+1]=time[k]+2.0/sum(n[k,:])   # The 2 is here because two individuals make contact at a time
    a=n[k,0]*(n[k,0]-1.0)/((n[k,0]+n[k,1])*(n[k,0]+n[k,1]-1))  # probability both players are type 0
    b=2*n[k,0]*n[k,1]/((n[k,0]+n[k,1])*(n[k,0]+n[k,1]-1.0))  # probability one player of each type
    U=np.random.rand()
    if U<=a:
        n[k+1,:]= n[k,:] + [2*F[0,0],0]
    elif a<U<=a+b:
        n[k+1,:]=n[k,:] + [F[0,1],F[1,0]]
    else:
        n[k+1,:]= n[k,:] + [0,2*F[1,1]]

plt.plot(time,n[:,0],'orange')
plt.plot(time,n[:,1],'blue')
plt.text(1.1,n[80,0], r'small',fontsize=14)
plt.text(1.1,n[80,1], r'large',fontsize=14)
plt.xlabel('time')
plt.ylabel('population size')
plt.title("Numbers of small and large crickets vs. time (simulation)")
# Out:
# Text(0.5, 1.0, 'Numbers of small and large crickets vs. time (simulation)')

# %% [markdown]
# The following code computes the deterministic analog of the cricket evolution.  The basic idea is that if the current population is [n[0], n[1]] then the drift (i.e. the expected rate of increase) of n[0] is n[0]  multiplied by the expected number of small crickets generated by a small cricket if an encounter happens.  That is true because each of the existing small crikets is having encounters at expected rate one.   To calculate the mean number of new small crickets generated by the encounter of a small cricket with a randomly selected other cricket, we use the law of total probability.  The encountered cricket is type zero with probabiity n[0]/(n[0]+n[1]), which results in F[0,0] new crickets of type zero, and the encountered cricket is type one with probability n[1]/(n[0]+n[1]), which results in F[0,1] new crickets of type zero.   Combining we get
# $$
# \dot{n}[0] = n[0]*(F[0,0]*n[0]+F[0,1]*n[1])/(n[0]+n[1])
# $$
# The equation just derived is based on the law of large numbers (LLN).  If the population is fairly large then no one individual plays a major role in the evolution.  Over a small period of time the ratios of small and large crickets is nearly constant, so the number of new crickets of each type in each time slot are nearly independent and identically distributed.   The LLN suggests approximating the sum of number of individuals of each type by the expected numbers of individuals of each type.  That's how we arrive at a deterministic differential equation.
#
# A similar expression holds for the derivative of n[1], and the two equations can be writen in matrix form as
# $$
# \dot{n} = diag(n)*F*n/sum(n)
# $$
# where diag(n) is the diagonal matrix with n[0] and n[1] on the diagonal, and "$*$" represents usual matrix multiplication.   (In the python code below, "$*$" denotes element by element multiplication, which is used instead of creating a diagonal matrix, and np.dot is used for ordinary matrix multiplication.)

# %%
# Deterministic (ODE) replicator dynamics for cricket game
from scipy.integrate import odeint

F=np.array([[5,1],[8,3]])  # fitness matrix

def f(n,t):
    return (n*np.dot(F,n)/sum(n)/1.)

ninit=[4,4]    # initial [number of small crickets, number of large crickets]
time=np.linspace(0.0,1.0, 1000)

n=odeint(f,ninit,time)

plt.plot(time,n[:,0],'orange')
plt.plot(time,n[:,1],'blue')
plt.xlabel('time')
plt.text(1.1,n[800,0], r'small',fontsize=14)
plt.text(1.1,n[800,1], r'large',fontsize=14)
plt.ylabel('population size')
plt.title("Numbers of small and large crickets vs. time (ode prediction)")
# Out:
# Text(0.5, 1.0, 'Numbers of small and large crickets vs. time (ode prediction)')

# %%
# Stochastic simulation of replicator dynamics for cricket game
# Time is scaled so contact rate of each individual is one per unit time
# The evolution trajectory is stored an plotted


def f(n,t):
    return (n*np.dot(F,n)/sum(n)/1.)
def simulate(x,y):
    F=np.array([[5,1],[8,3]])  # fitness matrix
    n_max=100  # maximum number of interactions
    n=np.zeros((n_max,2),dtype=float)
    time=np.zeros(n_max,dtype=float)
    
    n[0,0], n[0,1] = x, y # initial [number of small crickets, number of large crickets]
    
    for k in range(n_max-1):
        time[k+1]=time[k]+2.0/sum(n[k,:])   # The 2 is here because two individuals make contact at a time
        a=n[k,0]*(n[k,0]-1.0)/((n[k,0]+n[k,1])*(n[k,0]+n[k,1]-1))  # probability both players are type 0
        b=2*n[k,0]*n[k,1]/((n[k,0]+n[k,1])*(n[k,0]+n[k,1]-1.0))  # probability one player of each type
        U=np.random.rand()
        if U<=a:
            n[k+1,:]= n[k,:] + [2*F[0,0],0]
        elif a<U<=a+b:
            n[k+1,:]=n[k,:] + [F[0,1],F[1,0]]
        else:
            n[k+1,:]= n[k,:] + [0,2*F[1,1]]
    plt.figure(figsize= (15,6))
    plt.subplot(121)
    plt.plot(time,n[:,0],'orange')
    plt.plot(time,n[:,1],'blue')
    plt.text(1.1,n[80,0], r'small',fontsize=14)
    plt.text(1.1,n[80,1], r'large',fontsize=14)
    plt.xlabel('time')
    plt.ylabel('population size')
    plt.title("Numbers of small and large crickets vs. time (simulation)")
    
    ninit=[x,y]    # initial [number of small crickets, number of large crickets]
    time=np.linspace(0.0,1.5, 1000)
    
    n=odeint(f,ninit,time)
    plt.subplot(122)
    plt.plot(time,n[:,0],'orange')
    plt.plot(time,n[:,1],'blue')
    plt.xlabel('time')
    plt.text(1.1,n[800,0], r'small',fontsize=14)
    plt.text(1.1,n[800,1], r'large',fontsize=14)
    plt.ylabel('population size')
    plt.title("Numbers of small and large crickets vs. time (ode prediction)")
simulate(4,4)
simulate(0,4)
simulate(4,0)
simulate(10,1)

# %% [markdown]
# <br>**<SPAN style="BACKGROUND-COLOR: #C0C0C0">Problem 3:</SPAN>** Run the code above and compare the output to the output of the previous code for stochastic evolutionary dynamics.  Try different intial conditions such as [0,4], [4,0], and [10,1]. Comment on how the result of this compares to our previous simulation. Is the behavior similar?

# %% [markdown]
# __Answer__:
#
# <li> for the result of [0,4], the result shows that the simulation is much quicker than the ODE.
# <li> for the result of [4,0], the result shows that the ODE solution is much quicker than the simulation.
# <li> for the [10,1], the simulation is not so stable and the amount of small crickets is always larger than the large crickets.
# <li> over all, from my perspective, the solution of ODE is not so correctly accord to the simulation, discrete simulation is more precise but the solution of ODE may tell us more of a major trend.

# %% [markdown]
# **<SPAN style="BACKGROUND-COLOR: #C0C0C0">End of Problem 3</SPAN>**

# %% [markdown]
# If we let $\theta[0]=\frac{n[0]}{n[0]+n[1]}$ and $\theta[1]=\frac{n[1]}{n[0]+n[1]}$ then the vector $\theta=\binom{\theta[0]}{\theta[1]}$ describes the fractions of the popuation of each type.  It's entries sum to one.  Using the chain rule of calculus we can derive the following differential equation for $\theta$ from the above ode for $n$:
# $$
# \dot{\theta} = diag(\theta) \left( F\theta - \mathbf{1} \theta^T F \theta \right)
# $$
# where $\mathbf{1}$ is the column vector of ones (the derivation is a bit involved, try deriving it by yourself if interested, but it is not required). The two components of the vector $F \theta$ give the average fitness level of small crickets and large crickets, respectively, in an encounter with a cricket selected randomly from the population.   And $\theta^T F \theta$ is the weighted average of that vector, giving the average fitness over all crickets in the population.   Thus, $\theta[0]$ is increasing exactly when the fitness of small crickets is greater than the average fitness.
#
# <br>**<SPAN style="BACKGROUND-COLOR: #C0C0C0">Problem 4:</SPAN>**
#
# 1. Modify the above code to integrate the equation for the $\theta$ vector to obtain $\theta$ vs. time.
# To check your answer, compare it to what you get by first computing the trajectory of $n$ and then calculating $\theta$ from $n.$  (The code given above for deterministic evolution of n works for any number of types, not just two types. A problem below involves three types of individuals, so it'd be nice if you could implement your code for computing $\theta$ to work for any number of types.) __Be careful when you write your program, since matrix multiplication in Python can be tricky. Understand "$*$" multiplication and np.dot multiplication first. After each small step, debug, confirm, then proceed.__
# 2. Using the fact that $\theta[1]=1-\theta[0],$  a differential equation can be derived for the variable $\theta[0]$ alone.
# Plot the function $h$ on the interval $[0,1]$ such that $\dot{\theta}[0]=h(\theta[0]).$ Note that the horizontal axis of the graph is $\theta$, the vertical axis is $\dot{\theta}$. (You can just do this
# numerically.  It can also be done algebrically; in fact $h$ is a cubic polynomial, but it is a bit complicated to find the polynomial.)
# 3. What are the zeroes of $h$ (those are the equilibrium points of $\theta[0]$)?  Which of those are stable (in the sense that if $\theta[0]$ is slightly moved away from the equilibrium point, it returns to the equilibrium point)?

# %%
# Your code here
F=np.array([[5,1],[8,3]])  # fitness matrix
def f(theta,t):
    theta = np.array(theta)
    return theta*(F@theta-np.tile(theta,(len(theta),1))@F@theta)
print (f([0.5,0.5],1))

thetainit=[0.5,0.5]    # initial [number of small crickets, number of large crickets]
time=np.linspace(0.0,1.0, 1000)

n=odeint(f,thetainit,time)

plt.plot(time,n[:,0],'orange')
plt.plot(time,n[:,1],'blue')
plt.xlabel('time')
plt.text(1.1,n[800,0], r'small',fontsize=14)
plt.text(1.1,n[800,1], r'large',fontsize=14)
plt.ylabel('population size')
# Out:
# [-0.625  0.625]
# Text(0, 0.5, 'population size')

# %%
t = np.linspace(0,1,1000)
plt.plot(t,[f((t[i],1-t[i]),1)[0] for i in range(1000)])

# %% [markdown]
# __Answer:__ (Your answer here)
#
# if and only if theta = 0 or 1, the function would be 0. According to this figure, we can conclude that the small cricket would increase first and then gradually converge to 0.

# %% [markdown]
# **<SPAN style="BACKGROUND-COLOR: #C0C0C0">End of Problem 4</SPAN>**

# %% [markdown]
# The overall behavior in evolutionary games depends heavily on the fitness matrix $F.$   Another choice of $F$ corresponds to the so-called doves and hawks evolution game, for which the fitness matrix is
# $$\begin{array}{c|cc}  & dove & hawk  \\ \hline
#     dove & 3 & 1  \\
#     hawk & 5 & 0
#     \end{array}$$
# or by a fitness matrix
# $$F=\left( \begin{array}{cc}  3 & 1 \\ 5 & 0  \end{array}\right).$$   Think of the doves and hawks as two types of birds that need to share resources, such as food.  (The hawks are so aggressive that they attack the doves).  A dove has higher fitness, 3, against another dove than against a hawk, 1.  A hawk has a high fitness against a dove (5) but zero fitness against another hawk, because the hawks fight over their resources.
#
# <br>**<SPAN style="BACKGROUND-COLOR: #C0C0C0">Problem 5:</SPAN>**
#
# 1. Repeat the deterministic (ode) approach above, but now for the doves and hawks evolution game.   You can use either the random or deterministic evolution equations for the numerical analysis.
# 2. Comment and verify your assertions about equilibrium behavior by finding a differential equation for $\theta[0]$ and exploring its equilbrium points and their stability.

# %%
# Your code here
# part 1 code

def f(n,t):
    return (n*np.dot(F,n)/sum(n)/1.)
def simulate(x,y):
    F=np.array([[3,1],[5,0]])  # fitness matrix
    n_max=100  # maximum number of interactions
    n=np.zeros((n_max,2),dtype=float)
    time=np.zeros(n_max,dtype=float)
    
    n[0,0], n[0,1] = x, y # initial [number of dove, number of hawk]
    
    for k in range(n_max-1):
        time[k+1]=time[k]+2.0/sum(n[k,:])   # The 2 is here because two individuals make contact at a time
        a=n[k,0]*(n[k,0]-1.0)/((n[k,0]+n[k,1])*(n[k,0]+n[k,1]-1))  # probability both players are type 0
        b=2*n[k,0]*n[k,1]/((n[k,0]+n[k,1])*(n[k,0]+n[k,1]-1.0))  # probability one player of each type
        U=np.random.rand()
        if U<=a:
            n[k+1,:]= n[k,:] + [2*F[0,0],0]
        elif a<U<=a+b:
            n[k+1,:]=n[k,:] + [F[0,1],F[1,0]]
        else:
            n[k+1,:]= n[k,:] + [0,2*F[1,1]]
    plt.figure(figsize= (15,6))
    plt.subplot(121)
    plt.plot(time,n[:,0],'orange')
    plt.plot(time,n[:,1],'blue')
    plt.text(1.1,n[80,0], r'dove',fontsize=14)
    plt.text(1.1,n[80,1], r'hawk',fontsize=14)
    plt.xlabel('time')
    plt.ylabel('population size')
    plt.title("Numbers of dove and hawk vs. time (simulation)")
    
    ninit=[x,y]    # initial [number of dove, number of hawk]
    time=np.linspace(0.0,1.5, 1000)
    
    n=odeint(f,ninit,time)
    plt.subplot(122)
    plt.plot(time,n[:,0],'orange')
    plt.plot(time,n[:,1],'blue')
    plt.xlabel('time')
    plt.text(1.1,n[800,0], r'dove',fontsize=14)
    plt.text(1.1,n[800,1], r'hawk',fontsize=14)
    plt.ylabel('population size')
    plt.title("Numbers of dove and hawk vs. time (ode prediction)")
simulate(4,4)

# %%
# Your code here
F=np.array([[3,1],[5,0]])  # fitness matrix
def f(theta,t):
    theta = np.array(theta)
    return theta*(F@theta-np.tile(theta,(len(theta),1))@F@theta)
print (f([0.5,0.5],1))

thetainit=[0.5,0.5]    # initial [number of small crickets, number of large crickets]
time=np.linspace(0.0,1.0, 1000)

n=odeint(f,thetainit,time)

plt.plot(time,n[:,0],'orange')
plt.plot(time,n[:,1],'blue')
plt.xlabel('time')
plt.text(1.1,n[800,0], r'dove',fontsize=14)
plt.text(1.1,n[800,1], r'hawk',fontsize=14)
plt.ylabel('population size')
plt.figure()
t = np.linspace(0,1,1000)
plt.plot(t,[f((t[i],1-t[i]),1)[0] for i in range(1000)])
# Out:
# [-0.125  0.125]

# %% [markdown]
# __Answer__: (Your answer here)
# <li> From the result above, we can simply tell that both dove and hawk would be increasing in this kind of situation, there would not be the situation that we encontered in the cricket problem.
# <li> From the eq grapics we can tell that the dove would eventally be the 1/3 proportion. since the second phase graph we can see that 1/3 is the maximum eq point of this situation.

# %% [markdown]
# **<SPAN style="BACKGROUND-COLOR: #C0C0C0">End of Problem 5</SPAN>**

# %% [markdown]
# **<SPAN style="BACKGROUND-COLOR: #C0C0C0">Problem 6:</SPAN>**  Find a 3x3 fitness matrix $F$ and an initial condition for an evolutionary game with three types of individuals such that the solution $\theta$ has a limit cycle, not just converging to a limit point.  Does the limit cycle depend on the intial state for your fitness matrix?
#
# Hint 1: Adapt the code you wrote for Problem 4.
#
# Hint 2: Solve this problem by trial and error, i.e. trying different values of the entries in the fitness matrix. Think of the three types of individuals as three kinds of animals. What kind of relationship among these three animals would likely to cause an oscillating population for each animal?

# %%
# Your code here
# Your code here
F=np.array([[0,-20,20], [20,0,-20], [-20,20,0]])  # fitness matrix
def f(theta,t):
    theta = np.array(theta)
    return theta*(F@theta-np.tile(theta,(len(theta),1))@F@theta)
print (f([0.3,0.5,0.2],1))

thetainit=[0.3,0.5,0.2]    # initial [number of small crickets, number of large crickets]
time=np.linspace(0.0,1.0, 1000)

n=odeint(f,thetainit,time)

plt.plot(time,n[:,0],'orange')
plt.plot(time,n[:,1],'blue')
plt.plot(time,n[:,2],'green')
plt.xlabel('time')
plt.text(1.1,n[800,0], r'small',fontsize=14)
plt.text(1.1,n[800,1], r'large',fontsize=14)
plt.text(1.1,n[800,2], r'huge',fontsize=14)
plt.ylabel('population size')
# Out:
# [-1.8  1.   0.8]
# Text(0, 0.5, 'population size')

# %% [markdown]
# __Answer__: (Your answer here)
# If the three species are predatory to each other, a dynamic balance can be obtained.

# %% [markdown]
# **<SPAN style="BACKGROUND-COLOR: #C0C0C0">End of Problem 6</SPAN>**

# %% [markdown]
# For this week's lab, please answer all questions 1-6.

# %% [markdown]
# <div class="alert alert-block alert-warning">
# ## Academic Integrity Statement ##
#
# By submitting the lab with this statement, you declare you have written up the lab entirely by yourself, including both code and markdown cells. You also agree that you should not share your code with anyone else. Any violation of the academic integrity requirement may cause an academic integrity report to be filed that could go into your student record. See <a href="https://provost.illinois.edu/policies/policies/academic-integrity/students-quick-reference-guide-to-academic-integrity/">Students' Quick Reference Guide to Academic Integrity</a> for more information.
